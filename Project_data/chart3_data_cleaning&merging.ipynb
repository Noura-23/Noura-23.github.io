# %%
import pandas as pd

# %%
region_df=pd.read_csv("https://raw.githubusercontent.com/lukes/ISO-3166-Countries-with-Regional-Codes/refs/heads/master/all/all.csv")
region_df=region_df[["alpha-3", "region"]]
region_df
region_df = region_df.rename(columns={"alpha-3": "iso"})
region_df

# %%
tariffs_df=pd.read_csv("https://raw.githubusercontent.com/Noura-23/Noura-23.github.io/refs/heads/main/Project_data/chart3_tariffs_scraped.csv")
tariffs_df
tariffs_df=tariffs_df[["iso", "tariff_usd_per_kwh"]]
tariffs_df=tariffs_df.rename(columns={"country": "name", "tariff_usd_per_kwh": "tariffs"})
tariffs_df

# %%
raw_links = ["https://raw.githubusercontent.com/Noura-23/Noura-23.github.io/refs/heads/main/Project_data/population.csv", "https://raw.githubusercontent.com/Noura-23/Noura-23.github.io/refs/heads/main/Project_data/gdp_per_capita_ppp.csv"]
titles = ["Population", "GDP per capita, PPP"]
toskip = [4, 0]

cleaned_dfs = []

for i in range(2):
  df = pd.read_csv(raw_links[i], skiprows=toskip[i])
  df = df.rename(columns={"Country Code": "iso", "Country Name": "name", "2022": titles[i]})
  df = df[["name", "iso", titles[i]]]
  df = df.merge(region_df, on="iso")
  df = df.merge(tariffs_df, on="iso")
  df = df.query("region == 'Africa'")
  cleaned_dfs.append(df)

# merge the cleaned final dfs into a wide format
df = pd.merge(cleaned_dfs[0], cleaned_dfs[1], on=["name", "region", "iso"])
df
# Out:
#                 name  iso   Population  region  tariffs_x  \
# 0             Angola  AGO   35635029.0  Africa      0.013
# 1       Burkina Faso  BFA   22509038.0  Africa      0.219
# 2           Botswana  BWA    2439892.0  Africa      0.095
# 3           Cameroon  CMR   27632771.0  Africa      0.089
# 4         Cabo Verde  CPV     519741.0  Africa      0.170
# 5            Algeria  DZA   45477389.0  Africa      0.043
# 6   Egypt, Arab Rep.  EGY  112618250.0  Africa      0.023
# 7           Ethiopia  ETH  125384287.0  Africa      0.005
# 8              Gabon  GAB    2430747.0  Africa      0.218
# 9              Ghana  GHA   33149152.0  Africa      0.159
# 10             Kenya  KEN   54252461.0  Africa      0.222
# 11           Morocco  MAR   37329064.0  Africa      0.127
# 12              Mali  MLI   23072640.0  Africa      0.233
# 13        Mozambique  MOZ   32656246.0  Africa      0.127
# 14           Namibia  NAM    2889662.0  Africa      0.151
# 15           Nigeria  NGA  223150896.0  Africa      0.035
# 16            Rwanda  RWA   13651030.0  Africa      0.177
# 17           Senegal  SEN   17651103.0  Africa      0.194
# 18      Sierra Leone  SLE    8276807.0  Africa      0.253
# 19              Togo  TGO    9089738.0  Africa      0.206
# 20           Tunisia  TUN   12119334.0  Africa      0.068
# 21          Tanzania  TZA   64711821.0  Africa      0.094
# 22            Uganda  UGA   47312719.0  Africa      0.176
# 23      South Africa  ZAF   62378410.0  Africa      0.218
# 24            Zambia  ZMB   20152938.0  Africa      0.015
#
#     GDP per capita, PPP  tariffs_y
# 0           7924.888806      0.013
# 1           2641.870113      0.219
# 2          19976.834380      0.095
# 3           5188.977509      0.089
# 4           9481.073354      0.170
# 5          15836.094440      0.043
# 6          17526.801700      0.023
# 7           2844.922745      0.005
# 8          19992.557060      0.218
# 9           7208.157990      0.159
# 10          5883.223040      0.222
# 11          9283.925781      0.127
# 12          3008.755546      0.233
# 13          1581.944194      0.127
# 14         10662.701700      0.151
# 15          5948.726147      0.035
# 16          3098.677006      0.177
# 17          4530.220595      0.194
# 18          3146.792944      0.253
# 19          2852.064429      0.206
# 20         13608.072580      0.068
# 21          3799.862305      0.094
# 22          2919.177754      0.176
# 23         14759.435070      0.218
# 24          3840.724505      0.015

# %%
population_df = pd.read_csv("https://raw.githubusercontent.com/Noura-23/Noura-23.github.io/refs/heads/main/Project_data/population.csv", skiprows=4)
population_df

# %%
gdp_df = pd.read_csv("https://raw.githubusercontent.com/Noura-23/Noura-23.github.io/refs/heads/main/Project_data/gdp_per_capita_ppp.csv")
gdp_df

# %%
gdp_df = gdp_df[[]]
